# %% [markdown]
# <a href="https://colab.research.google.com/github/krfis/clthesis/blob/main/code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Installations & imports

# %%
! git clone https://github.com/machamp-nlp/machamp.git --quiet  # clones machamp

# %%
! cd machamp

# %%
! cd machamp; cat README.md | grep "requirements";  # requirements file
# Out:
# pip3 install --user -r requirements.txt

# %%
#! nvidia-smi  # gpu status

# %%
! cd machamp; pip3 install --user -r requirements.txt --quiet  # installs dependencies
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 594.2/594.2 kB 3.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 23.4 MB/s eta 0:00:00
#   Building wheel for jsonnet (setup.py) ... done

# %%
! export PATH=$PATH:/root/.local/bin

# %%
! pip install conllu --quiet
! pip install conll-df --quiet
# Out:
#   Preparing metadata (setup.py) ... done
#   Building wheel for conll-df (setup.py) ... done

# %%
import os
import random
import transformers
import pandas as pd

from conllu import parse
from conll_df import conll_df

# %%
#! rm -r /content/CLthesis  # first remove clone if necessary

# %%
! git clone https://github.com/krfis/clthesis.git --quiet # clones github repo with data

# %% [markdown]
# # Helper functions

# %%
def count_tokens(dataset):
  '''counts tokens in a conllu dataset
  returns token count : int'''

  counter = 0
  for sentence in dataset:
    for token in sentence:
      counter += 1
  return counter

# %%
def process(path):
  '''parses conllu file
  returns parsed conllu file : list(TokenList)'''

  with open(path, "r", encoding="utf-8") as dataset:
    input = dataset.read()
    parsed = parse(input)
  return parsed

# %%
def write(content):
  '''writes content of TokenLists to output file'''

  with open("output.conllu", "w", encoding="utf-8") as output:
    for sent in content:
      output.write(sent.serialize())

# %% [markdown]
# # Models

# %%
# old
#models = {
#    "xlm-r" : "FacebookAI/xlm-roberta-base",
#    "scandibert" : "vesteinn/ScandiBERT-no-faroese",
#    "icebert" : "mideind/IceBERT",
#    "norbert" : "patrickvonplaten/norwegian-roberta-base",
#    "swebert" : "birgermoell/roberta-swedish",
#    "danbert" : "DDSC/roberta-base-danish"
#}

# %%
models = {
    "xlm-r" : "xlm-roberta-base",
    "scandibert" : "ScandiBERT-no-faroese",
    "icebert" : "IceBERT",
    "norbert" : "norwegian-roberta-base",
    "swebert" : "roberta-swedish",
    "danbert" : "roberta-base-danish"
}

# %%
for modelname in models.values():
  print(modelname)
# Out:
# xlm-roberta-base
# ScandiBERT-no-faroese
# IceBERT
# norwegian-roberta-base
# roberta-swedish
# roberta-base-danish

# %% [markdown]
# # Pilot study 1

# %%
! mkdir -p machamp/data/pilot  # creates new folder for data

# %%
# copy files to data folder

! cp CLthesis/data/balanced/scandi-base/single-source/train-isl-60k.conllu machamp/data/pilot/  # train set
! cp CLthesis/data/balanced/scandi-base/single-source/dev-isl-6k.conllu machamp/data/pilot/  # dev set
! cp CLthesis/data/balanced/scandi-base/single-source/test-fao.conllu machamp/data/pilot/  # test set

# %%
! ls machamp/data/pilot  # contents of data folder
# Out:
# dev-isl-6k.conllu  test-fao.conllu  train-isl-60k.conllu

# %%
#! head machamp/data/pilot/*  # inspect files

# %%
train_path = "/content/machamp/data/pilot/train-isl-60k.conllu"
dev_path = "/content/machamp/data/pilot/dev-isl-6k.conllu"

# %%
train_df = conll_df(train_path, file_index=False)
dev_df = conll_df(dev_path, file_index=False)

# %%
train_df.head(3)
# Out:
#              w       l     x                 p  g       f Gender Type  \
# s i
# 1 1          Á    eiga   ADP            fs_þgf  2    case      _    _
#   2       loka     lok   ADV      no_ft_þgf_kk  4  advmod   Masc    _
#   3  mínútunum  mínúta  NOUN  no_ft_þgf_kvk_gr  2    conj    Fem    _
#
#     Definite Degree Mood Case Number Voice type Person Tense
# s i
# 1 1        _      _    _  Dat      _     _    _      _     _
#   2        _      _    _  Dat   Plur     _    _      _     _
#   3      Def      _    _  Dat   Plur     _    _      _     _

# %%
dev_df.head(3)
# Out:
#           w      l     x            p  g       f Gender Type Definite Degree  \
# s i
# 1 1      Um     um   ADV           eo  3  advmod      _    _        _      _
#   2     40%    40%   NUM     prósenta  3  nummod      _    _        _      _
#   3  álvera  álver  NOUN  no_ft_ef_hk  7   nsubj   Neut    _        _      _
#
#     Mood Case Number Voice type Person Tense
# s i
# 1 1    _    _      _     _    _      _     _
#   2    _    _      _     _    _      _     _
#   3    _  Gen   Plur     _    _      _     _

# %%
! cp /content/CLthesis/configs/config_pilot.json machamp/configs/  # copy dataset config file to config folder
! cp /content/CLthesis/configs/params_pilot.json machamp/configs/  # copy params file to config folder

# %%
! cat machamp/configs/config_pilot.json
# Out:
# {
#     "pilot" : {
#         "train_data_path" : "/content/machamp/data/pilot/train-isl-60k.conllu",
#         "dev_data_path" : "/content/machamp/data/pilot/dev-isl-6k.conllu",
#         "word_idx" : 1,
#         "tasks" : {
#             "upos" : {
#                 "task_type" : "seq",
#                 "column_idx" : 3,
#                 //"metric" : "accuracy",
#                 //"additional_metrics" : ["f1_micro", "f1_macro"]
#             },
#
#             "dependency" : {
#                 "task_type" : "dependency",
#                 "column_idx" : 6,
#                 //"metric" : "las",
#                 //"additional_metrics" : ["uas"]
#             }
#         }
#     }
# }

# %%
! cat machamp/configs/params_pilot.json
# Out:
# {
#   "transformer_model": "IceBERT",
#   "reset_transformer_model": false,
#   "random_seed": 8446,
#   "default_dec_dataset_embeds_dim": 12,
#   "encoder": {
#     "dropout": 0.2,
#     "max_input_length": 128,
#     "update_weights_encoder": true
#   },
#   "decoders": {
#     "default_decoder": {
#       "loss_weight": 1.0,
#       "metric": "accuracy",
#       "topn": 1,
#       "layers_to_use": [-1]
#     },
#     //"classification": {
#     //},
#     "dependency": {
#       "arc_representation_dim": 768,
#       "tag_representation_dim": 256,
#       "metric": "las",
#       "additional_metrics": "uas"
#     },
#     //"mlm": {
#     //  "metric": "perplexity"
#     //},
#     //"multiclas": {
#     //  "metric": "multi_acc",
#     //  "threshold": 0.7
#     //},
#     //"multiseq": {
#     //  "metric": "multi_acc",
#     //  "threshold": 0.7
#     //},
#     //"regression": {
#     //  "metric": "avg_dist"
#     //},
#     "seq": {
#       "metric": "accuracy",
#       "additional_metrics": ["f1_macro", "f1_micro"]
#     },
#     //"seq_bio": {
#     //  "metric": "span_f1"
#     //},
#     //"string2string": {
#     //},
#     //"tok": {
#     //  "pre_split": true
#     //}
#   },
#   "batching": {
#     "max_tokens": 1024,
#     "shuffle": true,
#     "batch_size": 32,
#     "sort_by_size": true,
#     "diverse": false,
#     "sampling_smoothing": 1.0 // 1.0 == original size, 0.0==all equal
#   },
#   "training": {
#     "keep_top_n": 1,
#     "learning_rate_scheduler": {
#       //"type": "slanted_triangular",
#       "cut_frac": 0.3,
#       "decay_factor": 0.38,
#       "discriminative_fine_tuning": true,
#       "gradual_unfreezing": true
#     },
#     "num_epochs": 20,
#     "optimizer": {
#       //"type": "adamw",
#       "betas": [
#         0.9,
#         0.99
#       ],
#       "lr": 0.0001,
#       //"correct_bias": false,
#       //"patience": 5, // disabled, because slanted_triangular changes the lr dynamically
#       "weight_decay": 0.01
#     }
#   }
# }

# %% [markdown]
# ## Training

# %%
! cd machamp; ls; python3 train.py --dataset_configs configs/config_pilot.json --parameters_config configs/params_pilot.json --name pilot --device 0  # set device to 1 for CPU
# Out:
# configs  docs	  logs	   predict.py  requirements.txt  scripts  train.py
# data	 LICENSE  machamp  README.md   results		 TODO
# 2024-03-02 13:19:12.305254: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-02 13:19:12.305309: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-02 13:19:12.306656: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-03-02 13:19:13.442655: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-03-02 13:19:14,499 - INFO - machamp.model.trainer - cmd: train.py --dataset_configs configs/config_pilot.json --parameters_config configs/params_pilot.json --name pilot --device 0
# 2024-03-02 13:19:14,539 - INFO - machamp.model.trainer - GPU: Tesla T4
# 2024-03-02 13:19:14,539 - INFO - machamp.model.trainer - Torch version: 2.1.0+cu121
# 2024-03-02 13:19:14,539 - INFO - machamp.model.trainer - Transformers version: 4.38.1
# 2024-03-02 13:19:14,540 - INFO - machamp.model.trainer - MaChAmp git version e162ab52c92deaca5e405cfb982fa79b8c1825d8
# 2024-03-02 13:19:14,902 - ERROR - STDERR -
# 2024-03-02 13:19:14,902 - ERROR - STDERR - tokenizer_config.json:   0%|          | 0.00/940 [00:00<?, ?B/s]
# 2024-03-02 13:19:14,903 - ERROR - STDERR -
# 2024-03-02 13:19:14,903 - ERROR - STDERR - tokenizer_config.json: 100%|##########| 940/940 [00:00<00:00, 4.88MB/s]
# 2024-03-02 13:19:15,051 - ERROR - STDERR -
# 2024-03-02 13:19:15,051 - ERROR - STDERR - config.json:   0%|          | 0.00/516 [00:00<?, ?B/s]
# 2024-03-02 13:19:15,051 - ERROR - STDERR -
# 2024-03-02 13:19:15,052 - ERROR - STDERR - config.json: 100%|##########| 516/516 [00:00<00:00, 3.24MB/s]
# 2024-03-02 13:19:15,213 - ERROR - STDERR -
# 2024-03-02 13:19:15,213 - ERROR - STDERR - vocab.json:   0%|          | 0.00/1.03M [00:00<?, ?B/s]
# 2024-03-02 13:19:15,267 - ERROR - STDERR -
# 2024-03-02 13:19:15,267 - ERROR - STDERR - vocab.json: 100%|##########| 1.03M/1.03M [00:00<00:00, 19.2MB/s]
# 2024-03-02 13:19:15,383 - ERROR - STDERR -
# 2024-03-02 13:19:15,383 - ERROR - STDERR - merges.txt:   0%|          | 0.00/595k [00:00<?, ?B/s]
# 2024-03-02 13:19:15,483 - ERROR - STDERR -
# 2024-03-02 13:19:15,483 - ERROR - STDERR - merges.txt: 100%|##########| 595k/595k [00:00<00:00, 5.98MB/s]
# 2024-03-02 13:19:15,656 - ERROR - STDERR -
# 2024-03-02 13:19:15,656 - ERROR - STDERR - special_tokens_map.json:   0%|          | 0.00/772 [00:00<?, ?B/s]
# 2024-03-02 13:19:15,657 - ERROR - STDERR -
# 2024-03-02 13:19:15,657 - ERROR - STDERR - special_tokens_map.json: 100%|##########| 772/772 [00:00<00:00, 3.88MB/s]
# 2024-03-02 13:19:15,794 - INFO - machamp.data.machamp_dataset - Reading /content/machamp/data/pilot/train-isl-60k.conllu...
# 2024-03-02 13:19:23,290 - INFO - machamp.readers.read_sequence - Stats pilot (/content/machamp/data/pilot/train-isl-60k.conllu):
# 2024-03-02 13:19:23,290 - INFO - machamp.readers.read_sequence - Lines:      3,010
# 2024-03-02 13:19:23,290 - INFO - machamp.readers.read_sequence - Words:      60,289
# 2024-03-02 13:19:23,291 - INFO - machamp.readers.read_sequence - Subwords:   89,750
# 2024-03-02 13:19:23,291 - INFO - machamp.readers.read_sequence - Unks:       0
# 2024-03-02 13:19:23,291 - INFO - machamp.readers.read_sequence - Pre-splits: 0
# 2024-03-02 13:19:23,293 - INFO - machamp.data.machamp_dataset - Done reading /content/machamp/data/pilot/train-isl-60k.conllu (7.0s)
#
# 2024-03-02 13:19:23,294 - ERROR - STDERR - /usr/local/lib/python3.10/dist-packages/torch/utils/data/sampler.py:64: UserWarning: `data_source` argument is not used and will be removed in 2.2.0.You may still have custom implementation that utilizes it.
# 2024-03-02 13:19:23,294 - ERROR - STDERR -   warnings.warn("`data_source` argument is not used and will be removed in 2.2.0."
# 2024-03-02 13:19:23,445 - INFO - machamp.data.machamp_dataset - Reading /content/machamp/data/pilot/dev-isl-6k.conllu...
# 2024-03-02 13:19:24,123 - INFO - machamp.readers.read_sequence - Stats pilot (/content/machamp/data/pilot/dev-isl-6k.conllu):
# 2024-03-02 13:19:24,123 - INFO - machamp.readers.read_sequence - Lines:      310
# 2024-03-02 13:19:24,123 - INFO - machamp.readers.read_sequence - Words:      5,997
# 2024-03-02 13:19:24,123 - INFO - machamp.readers.read_sequence - Subwords:   8,904
# 2024-03-02 13:19:24,123 - INFO - machamp.readers.read_sequence - Unks:       0
# 2024-03-02 13:19:24,123 - INFO - machamp.readers.read_sequence - Pre-splits: 0
# 2024-03-02 13:19:24,123 - INFO - machamp.data.machamp_dataset - Done reading /content/machamp/data/pilot/dev-isl-6k.conllu (0.0s)
#
# 2024-03-02 13:19:24,781 - ERROR - STDERR -
# 2024-03-02 13:19:24,781 - ERROR - STDERR - model.safetensors:   0%|          | 0.00/652M [00:00<?, ?B/s]
# 2024-03-02 13:19:24,889 - ERROR - STDERR -
# 2024-03-02 13:19:24,890 - ERROR - STDERR - model.safetensors:   2%|1         | 10.5M/652M [00:00<00:06, 97.0MB/s]
# 2024-03-02 13:19:24,996 - ERROR - STDERR -
# 2024-03-02 13:19:24,996 - ERROR - STDERR - model.safetensors:   5%|4         | 31.5M/652M [00:00<00:03, 155MB/s]
# 2024-03-02 13:19:25,099 - ERROR - STDERR -
# 2024-03-02 13:19:25,100 - ERROR - STDERR - model.safetensors:   8%|8         | 52.4M/652M [00:00<00:03, 177MB/s]
# 2024-03-02 13:19:25,245 - ERROR - STDERR -
# 2024-03-02 13:19:25,245 - ERROR - STDERR - model.safetensors:  13%|#2        | 83.9M/652M [00:00<00:02, 195MB/s]
# 2024-03-02 13:19:25,385 - ERROR - STDERR -
# 2024-03-02 13:19:25,385 - ERROR - STDERR - model.safetensors:  18%|#7        | 115M/652M [00:00<00:02, 207MB/s]
# 2024-03-02 13:19:25,498 - ERROR - STDERR -
# 2024-03-02 13:19:25,498 - ERROR - STDERR - model.safetensors:  21%|##        | 136M/652M [00:00<00:02, 200MB/s]
# 2024-03-02 13:19:25,644 - ERROR - STDERR -
# 2024-03-02 13:19:25,644 - ERROR - STDERR - model.safetensors:  26%|##5       | 168M/652M [00:00<00:02, 206MB/s]
# 2024-03-02 13:19:25,749 - ERROR - STDERR -
# 2024-03-02 13:19:25,749 - ERROR - STDERR - model.safetensors:  29%|##8       | 189M/652M [00:00<00:02, 204MB/s]
# 2024-03-02 13:19:25,854 - ERROR - STDERR -
# 2024-03-02 13:19:25,854 - ERROR - STDERR - model.safetensors:  32%|###2      | 210M/652M [00:01<00:02, 203MB/s]
# 2024-03-02 13:19:25,962 - ERROR - STDERR -
# 2024-03-02 13:19:25,962 - ERROR - STDERR - model.safetensors:  35%|###5      | 231M/652M [00:01<00:02, 200MB/s]
# 2024-03-02 13:19:26,073 - ERROR - STDERR -
# 2024-03-02 13:19:26,073 - ERROR - STDERR - model.safetensors:  39%|###8      | 252M/652M [00:01<00:02, 197MB/s]
# 2024-03-02 13:19:26,183 - ERROR - STDERR -
# 2024-03-02 13:19:26,183 - ERROR - STDERR - model.safetensors:  42%|####1     | 273M/652M [00:01<00:01, 195MB/s]
# 2024-03-02 13:19:26,287 - ERROR - STDERR -
# 2024-03-02 13:19:26,287 - ERROR - STDERR - model.safetensors:  45%|####5     | 294M/652M [00:01<00:01, 197MB/s]
# 2024-03-02 13:19:26,391 - ERROR - STDERR -
# 2024-03-02 13:19:26,392 - ERROR - STDERR - model.safetensors:  48%|####8     | 315M/652M [00:01<00:01, 198MB/s]
# 2024-03-02 13:19:26,492 - ERROR - STDERR -
# 2024-03-02 13:19:26,492 - ERROR - STDERR - model.safetensors:  51%|#####1    | 336M/652M [00:01<00:01, 201MB/s]
# 2024-03-02 13:19:26,637 - ERROR - STDERR -
# 2024-03-02 13:19:26,637 - ERROR - STDERR - model.safetensors:  56%|#####6    | 367M/652M [00:01<00:01, 207MB/s]
# 2024-03-02 13:19:26,779 - ERROR - STDERR -
# 2024-03-02 13:19:26,779 - ERROR - STDERR - model.safetensors:  61%|######1   | 398M/652M [00:01<00:01, 212MB/s]
# 2024-03-02 13:19:26,938 - ERROR - STDERR -
# 2024-03-02 13:19:26,939 - ERROR - STDERR - model.safetensors:  66%|######5   | 430M/652M [00:02<00:01, 207MB/s]
# 2024-03-02 13:19:27,047 - ERROR - STDERR -
# 2024-03-02 13:19:27,047 - ERROR - STDERR - model.safetensors:  69%|######9   | 451M/652M [00:02<00:00, 203MB/s]
# 2024-03-02 13:19:27,154 - ERROR - STDERR -
# 2024-03-02 13:19:27,155 - ERROR - STDERR - model.safetensors:  72%|#######2  | 472M/652M [00:02<00:00, 201MB/s]
# 2024-03-02 13:19:27,263 - ERROR - STDERR -
# 2024-03-02 13:19:27,263 - ERROR - STDERR - model.safetensors:  76%|#######5  | 493M/652M [00:02<00:00, 199MB/s]
# 2024-03-02 13:19:27,371 - ERROR - STDERR -
# 2024-03-02 13:19:27,371 - ERROR - STDERR - model.safetensors:  79%|#######8  | 514M/652M [00:02<00:00, 198MB/s]
# 2024-03-02 13:19:27,608 - ERROR - STDERR -
# 2024-03-02 13:19:27,608 - ERROR - STDERR - model.safetensors:  82%|########2 | 535M/652M [00:02<00:00, 146MB/s]
# 2024-03-02 13:19:27,755 - ERROR - STDERR -
# 2024-03-02 13:19:27,756 - ERROR - STDERR - model.safetensors:  87%|########6 | 566M/652M [00:02<00:00, 166MB/s]
# 2024-03-02 13:19:27,857 - ERROR - STDERR -
# 2024-03-02 13:19:27,858 - ERROR - STDERR - model.safetensors:  90%|######### | 587M/652M [00:03<00:00, 175MB/s]
# 2024-03-02 13:19:27,998 - ERROR - STDERR -
# 2024-03-02 13:19:27,998 - ERROR - STDERR - model.safetensors:  93%|#########3| 608M/652M [00:03<00:00, 167MB/s]
# 2024-03-02 13:19:28,166 - ERROR - STDERR -
# 2024-03-02 13:19:28,166 - ERROR - STDERR - model.safetensors:  97%|#########6| 629M/652M [00:03<00:00, 153MB/s]
# 2024-03-02 13:19:28,277 - ERROR - STDERR -
# 2024-03-02 13:19:28,277 - ERROR - STDERR - model.safetensors: 100%|##########| 652M/652M [00:03<00:00, 165MB/s]
# 2024-03-02 13:19:28,278 - ERROR - STDERR -
# 2024-03-02 13:19:28,279 - ERROR - STDERR - model.safetensors: 100%|##########| 652M/652M [00:03<00:00, 186MB/s]
# 2024-03-02 13:19:29,138 - INFO - machamp.model.machamp - Overview of the torch model:
# 2024-03-02 13:19:29,138 - INFO - machamp.model.machamp - MachampModel(
#   (mlm): RobertaModel(
#     (embeddings): RobertaEmbeddings(
#       (word_embeddings): Embedding(50000, 768, padding_idx=1)
#       (position_embeddings): Embedding(514, 768, padding_idx=1)
#       (token_type_embeddings): Embedding(1, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): RobertaEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x RobertaLayer(
#           (attention): RobertaAttention(
#             (self): RobertaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): RobertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): RobertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): RobertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): RobertaPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (dropout): Dropout(p=0.2, inplace=False)
#   (decoders): ModuleDict(
#     (dependency): MachampDepDecoder(
#       (head_arc_feedforward): Linear(in_features=768, out_features=768, bias=True)
#       (child_arc_feedforward): Linear(in_features=768, out_features=768, bias=True)
#       (arc_attention): BilinearMatrixAttention()
#       (head_tag_feedforward): Linear(in_features=768, out_features=256, bias=True)
#       (child_tag_feedforward): Linear(in_features=768, out_features=256, bias=True)
#       (tag_bilinear): Bilinear(in1_features=256, in2_features=256, out_features=30, bias=True)
#       (decoder_dropout): Dropout(p=0.0, inplace=False)
#     )
#     (upos): MachampSeqDecoder(
#       (hidden_to_label): Linear(in_features=768, out_features=17, bias=True)
#       (loss_function): CrossEntropyLoss()
#       (decoder_dropout): Dropout(p=0.0, inplace=False)
#     )
#   )
#   (scalars): ModuleDict(
#     (dependency): None
#     (upos): None
#   )
#   (dataset_embedder): Embedding(1, 768)
# )
# 2024-03-02 13:19:29,186 - INFO - machamp.utils.myutils - Done constructing parameter groups.
# 2024-03-02 13:19:29,186 - INFO - machamp.utils.myutils - Group 0: ['mlm.encoder.layer.7.attention.self.query.bias', 'mlm.encoder.layer.0.output.LayerNorm.bias', 'mlm.encoder.layer.4.attention.self.value.weight', 'mlm.encoder.layer.6.attention.output.dense.bias', 'mlm.encoder.layer.2.intermediate.dense.bias', 'mlm.encoder.layer.8.output.LayerNorm.bias', 'mlm.encoder.layer.7.output.dense.bias', 'mlm.encoder.layer.9.output.LayerNorm.bias', 'mlm.encoder.layer.10.output.LayerNorm.weight', 'mlm.encoder.layer.5.attention.output.dense.weight', 'mlm.encoder.layer.9.attention.self.key.bias', 'mlm.encoder.layer.1.output.LayerNorm.weight', 'mlm.encoder.layer.1.attention.self.key.weight', 'mlm.encoder.layer.3.attention.self.value.bias', 'mlm.encoder.layer.8.attention.output.dense.bias', 'mlm.encoder.layer.10.intermediate.dense.bias', 'mlm.encoder.layer.0.attention.output.dense.bias', 'mlm.encoder.layer.10.attention.output.dense.bias', 'mlm.encoder.layer.10.attention.self.query.weight', 'mlm.encoder.layer.10.attention.self.value.bias', 'mlm.encoder.layer.6.attention.self.value.bias', 'mlm.encoder.layer.1.attention.self.value.bias', 'mlm.encoder.layer.0.attention.self.value.weight', 'mlm.encoder.layer.11.output.LayerNorm.bias', 'mlm.encoder.layer.10.attention.self.value.weight', 'mlm.encoder.layer.4.attention.self.key.bias', 'mlm.encoder.layer.10.attention.output.LayerNorm.weight', 'mlm.encoder.layer.0.attention.output.dense.weight', 'mlm.encoder.layer.6.output.dense.weight', 'mlm.encoder.layer.0.attention.self.key.bias', 'mlm.encoder.layer.10.attention.self.key.bias', 'mlm.encoder.layer.6.intermediate.dense.bias', 'mlm.encoder.layer.7.attention.output.LayerNorm.weight', 'mlm.encoder.layer.2.output.LayerNorm.bias', 'mlm.pooler.dense.weight', 'mlm.encoder.layer.6.attention.self.key.weight', 'mlm.encoder.layer.0.output.dense.weight', 'mlm.encoder.layer.6.output.dense.bias', 'mlm.encoder.layer.10.attention.output.LayerNorm.bias', 'mlm.encoder.layer.6.output.LayerNorm.bias', 'mlm.encoder.layer.2.attention.output.dense.weight', 'mlm.encoder.layer.5.attention.self.key.weight', 'mlm.encoder.layer.9.intermediate.dense.weight', 'mlm.encoder.layer.11.attention.self.query.bias', 'mlm.encoder.layer.6.attention.self.key.bias', 'mlm.encoder.layer.6.attention.output.LayerNorm.weight', 'mlm.encoder.layer.3.attention.self.value.weight', 'mlm.encoder.layer.7.intermediate.dense.bias', 'mlm.encoder.layer.6.attention.output.LayerNorm.bias', 'mlm.encoder.layer.2.attention.output.LayerNorm.weight', 'mlm.encoder.layer.5.attention.output.LayerNorm.weight', 'mlm.embeddings.LayerNorm.weight', 'mlm.encoder.layer.2.attention.output.dense.bias', 'mlm.encoder.layer.9.attention.self.query.bias', 'mlm.encoder.layer.7.attention.output.dense.weight', 'mlm.encoder.layer.6.attention.self.value.weight', 'mlm.encoder.layer.9.intermediate.dense.bias', 'mlm.encoder.layer.5.intermediate.dense.bias', 'mlm.encoder.layer.4.attention.output.dense.bias', 'mlm.encoder.layer.3.attention.self.query.bias', 'mlm.encoder.layer.3.attention.self.query.weight', 'mlm.encoder.layer.6.output.LayerNorm.weight', 'mlm.encoder.layer.8.attention.self.value.bias', 'mlm.encoder.layer.3.intermediate.dense.bias', 'mlm.encoder.layer.0.attention.self.key.weight', 'mlm.encoder.layer.9.attention.self.value.bias', 'mlm.encoder.layer.0.attention.self.query.weight', 'mlm.encoder.layer.7.attention.output.dense.bias', 'mlm.encoder.layer.3.attention.self.key.weight', 'mlm.encoder.layer.3.attention.self.key.bias', 'mlm.encoder.layer.4.output.dense.bias', 'mlm.encoder.layer.0.output.dense.bias', 'mlm.encoder.layer.1.attention.output.dense.weight', 'mlm.encoder.layer.6.attention.output.dense.weight', 'mlm.encoder.layer.2.output.dense.weight', 'mlm.encoder.layer.4.intermediate.dense.bias', 'mlm.encoder.layer.11.output.dense.bias', 'mlm.encoder.layer.11.output.dense.weight', 'mlm.encoder.layer.3.output.LayerNorm.bias', 'mlm.encoder.layer.11.attention.output.dense.bias', 'mlm.encoder.layer.11.output.LayerNorm.weight', 'mlm. ...
# 2024-03-02 13:19:29,186 - INFO - machamp.utils.myutils - Group 1: ['dataset_embedder.weight', 'decoders.dependency._head_sentinel', 'decoders.dependency.head_tag_feedforward.weight', 'decoders.dependency.head_arc_feedforward.bias', 'decoders.upos.hidden_to_label.weight', 'decoders.dependency.head_tag_feedforward.bias', 'decoders.dependency.arc_attention._weight_matrix', 'decoders.dependency.tag_bilinear.bias', 'decoders.dependency.head_arc_feedforward.weight', 'decoders.dependency.child_tag_feedforward.bias', 'decoders.dependency.child_tag_feedforward.weight', 'decoders.dependency.arc_attention._bias', 'decoders.dependency.child_arc_feedforward.weight', 'decoders.dependency.child_arc_feedforward.bias', 'decoders.upos.hidden_to_label.bias', 'decoders.dependency.tag_bilinear.weight'], {}
# 2024-03-02 13:19:29,186 - INFO - machamp.utils.myutils - Group 2: [], {}
# 2024-03-02 13:19:29,186 - WARNING - machamp.utils.myutils - When constructing parameter groups, scalars.* does not match any parameter name
# 2024-03-02 13:19:29,188 - INFO - machamp.utils.myutils - Number of trainable parameters: 128589105
# 2024-03-02 13:19:29,195 - ERROR - STDERR - /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:429: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
# 2024-03-02 13:19:29,195 - ERROR - STDERR -   warnings.warn(
# 2024-03-02 13:19:29,555 - INFO - machamp.modules.allennlp.slanted_triangular - Gradual unfreezing. Training only the decoder heads, not the MLM.
# 2024-03-02 13:19:29,557 - INFO - machamp.model.trainer - MaChAmp succesfully initialized in 15.0s
# 2024-03-02 13:19:29,557 - INFO - machamp.model.trainer -
#
#           CHAMP!                   %%#/
#  ###/%(        CHAMP!            ,#//(%%#(
# #%%/((/(            . , ,       .%%#####%(
# #(/(((###(        ////////%     *//((((((/
#   ,((((//        #%(%#/#%%/          &####
#      ###### *#%%@&((//&@#%&(%%#%%%%#%%####
#      ,####(%%###%#&&&#((&&(((%%%%########(
#        ///((%%%##/%%######((%%%%%%%%((((//
#           %%%%%##((/%(///%%##%%%%%%%##
#         /%%####%%%%%%#%%#/(%#(((%%%%%&.
#        &#%/#%%###%%%##%%%((###(//(####(
#      @&%%#////(########%######((/(////(
#        #////     ((((##(((((////,
#                    */(//(((/**,.
#                   #,**%#%,*,,,*(
#                /%%%%%/,,,,,(%%%%((
#               &%%%#(((/*  /(#%%%#(/
#               %%#(((//     ,((###(/
#              .%(/(/,         /(###/(
#               %(((//          (/((///
#                ((/,             /(//
#              %%%#((,            &%%%#
#          /#(#%(/,             /###*##*
#
# 2024-03-02 13:19:29,557 - INFO - machamp.model.trainer - starting training...
# 2024-03-02 13:19:29,557 - INFO - machamp.model.trainer - Epoch 1/20: training
# 100% 112/112 [00:35<00:00,  3.13it/s]
# 2024-03-02 13:20:05,392 - INFO - machamp.modules.allennlp.slanted_triangular - Learning rates for each group:
#
# 2024-03-02 13:20:05,392 - INFO - machamp.modules.allennlp.slanted_triangular - 0: 3.125e-06
# 2024-03-02 13:20:05,392 - INFO - machamp.modules.allennlp.slanted_triangular - 1: 3.125e-06
# 2024-03-02 13:20:05,392 - INFO - machamp.modules.allennlp.slanted_triangular - 2: 1.1875e-06
# 2024-03-02 13:20:05,393 - INFO - machamp.modules.allennlp.slanted_triangular - Gradual unfreezing finished. Training all layers.
# 2024-03-02 13:20:05,393 - INFO - machamp.model.trainer - Epoch 1: evaluating on dev
# 100% 12/12 [00:02<00:00,  4.33it/s]
# 2024-03-02 13:20:08,165 - INFO - machamp.model.callback - epoch       : 1/20
# 2024-03-02 13:20:08,165 - INFO - machamp.model.callback - best_epoch  : 1
# 2024-03-02 13:20:08,165 - INFO - machamp.model.callback - max_gpu_mem : 1.4782
# 2024-03-02 13:20:08,165 - INFO - machamp.model.callback - cur_ram     : 1.7832
# 2024-03-02 13:20:08,165 - INFO - machamp.model.callback - time_epoch  : 0:00:38
# 2024-03-02 13:20:08,166 - INFO - machamp.model.callback - time_total  : 0:00:38
# 2024-03-02 13:20:08,166 - INFO - machamp.model.callback -
# 2024-03-02 13:20:08,166 - INFO - machamp.model.callback -                train_loss dev_loss train_scores dev_scores
# 2024-03-02 13:20:08,166 - INFO - machamp.model.callback - Best (1)
# 2024-03-02 13:20:08,166 - INFO - machamp.model.callback - dependency_las     7.0585   4.0315       0.0472     0.1608
# 2024-03-02 13:20:08,166 - INFO - machamp.model.callback - upos_accuracy      2.7007   2.5352       0.1402     0.2049
# 2024-03-02 13:20:08,166 - INFO - machamp.model.callback - sum                9.7593   6.5667       0.1874     0.3658
# 2024-03-02 13:20:08,166 - INFO - machamp.model.callback - Epoch 1
# 2024-03-02 13:20:08,166 - INFO - machamp.model.callback - dependency_las     7.0585   4.0315       0.0472     0.1608
# 2024-03-02 13:20:08,166 - INFO - machamp.model.callback - upos_accuracy      2.7007   2.5352       0.1402     0.2049
# 2024-03-02 13:20:08,166 - INFO - machamp.model.callback - sum                9.7593   6.5667       0.1874     0.3658
# 2024-03-02 13:20:08,199 - INFO - machamp.model.callback -
#                 Dev scores (y) over epochs (x)
# ┌────────────────────────────────────────────────────────────┐
# ││                             ▘                             │
# ││                                                           │ 0.20
# ││                                                           │
# ││                                                           │
# ││                                                           │
# ││                                                           │ 0.19
# ││                                                           │
# ││                                                           │
# ││                                                           │
# ││                                                           │ 0.18
# ││                                                           │
# ││                                                           │
# ││                                                           │
# ││                                                           │ 0.17
# ││                                                           │
# ││                                                           │
# ││                             ▖                             │
# └────────────────────────────────────────────────────────────┘
# 0.0            0.5            1.0            1.5
#                         ██ dependency
#                         ██ upos
# 2024-03-02 13:20:08,199 - INFO - machamp.model.callback - Performance of 0.3658 within top 1 models, saving to logs/pilot/2024.03.02_13.19.14/model_1.pt
# 2024-03-02 13:20:09,587 - INFO - machamp.model.trainer - Epoch 2/20: training
# 100% 112/112 [00:52<00:00,  2.12it/s]
# 2024-03-02 13:21:02,299 - INFO - machamp.modules.allennlp.slanted_triangular - Learning rates for each group:
#
# 2024-03-02 13:21:02,299 - INFO - machamp.modules.allennlp.slanted_triangular - 0: 2.013126959247649e-05
# 2024-03-02 13:21:02,299 - INFO - machamp.modules.allennlp.slanted_triangular - 1: 2.013126959247649e-05
# 2024-03-02 13:21:02,299 - INFO - machamp.modules.allennlp.slanted_triangular - 2: 7.649882445141066e-06
# 2024-03-02 13:21:02,300 - INFO - machamp.modules.allennlp.slanted_triangular - Gradual unfreezing finished. Training all layers.
# 2024-03-02 13:21:02,300 - INFO - machamp.model.trainer - Epoch 2: evaluating on dev
# 100% 12/12 [00:02<00:00,  4.25it/s]
# 2024-03-02 13:21:05,125 - INFO - machamp.model.callback - epoch       : 2/20
# 2024-03-02 13:21:05,125 - INFO - machamp.model.callback - best_epoch  : 2
# 2024-03-02 13:21:05,125 - INFO - machamp.model.callback - max_gpu_mem : 2.9779
# 2024-03-02 13:21:05,125 - INFO - machamp.model.callback - cur_ram     : 1.7972
# 2024-03-02 13:21:05,125 - INFO - machamp.model.callback - time_epoch  : 0:00:55
# 2024-03-02 13:21:05,125 - INFO - machamp.model.callback - time_total  : 0:01:35
# 2024-03-02 13:21:05,125 - INFO - machamp.model.callback -
# 2024-03-02 13:21:05,125 - INFO - machamp.model.callback -                train_loss dev_loss train_scores dev_scores
# 2024-03-02 13:21:05,125 - INFO - machamp.model.callback - Best (2)
# 2024-03-02 13:21:05,125 - INFO - machamp.model.callback - dependency_las     4.4630   3.2031       0.1154     0.2703
# 2024-03-02 13:21:05,125 - INFO - machamp.model.callback - upos_accuracy      2.4691   2.2509       0.2081     0.3652
# 2024-03-02 13:21:05,126 - INFO - machamp.model.callback - sum                6.9321   5.4540       0.3235     0.6355
# 2024-03-02 13:21:05,126 - INFO - machamp.model.callback - Epoch 2
# 2024-03-02 13:21:05,126 - INFO - machamp.model.callback - dependency_las     4.4630   3.2031       0.1154     0.2703
# 2024-03-02 13:21:05,126 - INFO - machamp.model.callback - upos_accuracy      2.4691   2.2509       0.2081     0.3652
# 2024-03-02 13:21:05,126 - INFO - machamp.model.callback - sum                6.9321   5.4540       0.3235     0.6355
# 2024-03-02 13:21:05,148 - INFO - machamp.model.callback -
#                 Dev scores (y) over epochs (x)
# ┌────────────────────────────────────────────────────────────┐
# │                                                       ▗▄▄▀▀│
# │                                                   ▄▄▞▀▘    │ 0.35
# │                                              ▗▄▄▀▀         │
# │                                          ▄▄▞▀▘             │
# │                                     ▗▄▄▀▀                  │
# │                                 ▄▄▞▀▘                      │ 0.30
# │                            ▗▄▄▀▀                           │
# │                        ▄▄▞▀▘                              ▗│
# │                   ▗▄▄▀▀                            ▗▄▄▄▀▀▀▘│
# │               ▄▄▞▀▘                          ▄▄▄▞▀▀▘       │ 0.25
# │          ▗▄▄▀▀                        ▗▄▄▄▀▀▀              │
# │      ▄▄▞▀▘                      ▄▄▄▀▀▀▘                    │
# │ ▗▄▄▀▀                    ▗▄▄▞▀▀▀                           │
# │▀▘                 ▗▄▄▄▀▀▀▘                                 │ 0.20
# │             ▄▄▄▞▀▀▘                                        │
# │      ▗▄▄▄▀▀▀                                               │
# │▄▄▄▀▀▀▘                                                     │
# └────────────────────────────────────────────────────────────┘
# 1.0                           1.5                          2.0
#                         ██ dependency
#                         ██ upos
# 2024-03-02 13:21:05,148 - INFO - machamp.model.callback - Performance of 0.6355 within top 1 models, saving to logs/pilot/2024.03.02_13.19.14/model_2.pt
# 2024-03-02 13:21:06,521 - INFO - machamp.model.callback - Removing old model: logs/pilot/2024.03.02_13.19.14/model_1.pt
# 2024-03-02 13:21:06,602 - INFO - machamp.model.trainer - Epoch 3/20: training
# 100% 112/112 [00:52<00:00,  2.14it/s]
# 2024-03-02 13:21:58,915 - INFO - machamp.modules.allennlp.slanted_triangular - Learning rates for each group:
#
# 2024-03-02 13:21:58,916 - INFO - machamp.modules.allennlp.slanted_triangular - 0: 3.713753918495298e-05
# 2024-03-02 13:21:58,916 - INFO - machamp.modules.allennlp.slanted_triangular - 1: 3.713753918495298e-05
# 2024-03-02 13:21:58,916 - INFO - machamp.modules.allennlp.slanted_triangular - 2: 1.4112264890282133e-05
# 2024-03-02 13:21:58,916 - INFO - machamp.modules.allennlp.slanted_triangular - Gradual unfreezing finished. Training all layers.
# 2024-03-02 13:21:58,916 - INFO - machamp.model.trainer - Epoch 3: evaluating on dev
# 100% 12/12 [00:03<00:00,  3.43it/s]
# 2024-03-02 13:22:02,416 - INFO - machamp.model.callback - epoch       : 3/20
# 2024-03-02 13:22:02,417 - INFO - machamp.model.callback - best_epoch  : 3
# 2024-03-02 13:22:02,417 - INFO - machamp.model.callback - max_gpu_mem : 2.9916
# 2024-03-02 13:22:02,417 - INFO - machamp.model.callback - cur_ram     : 1.7973
# 2024-03-02 13:22:02,417 - INFO - machamp.model.callback - time_epoch  : 0:00:55
# 2024-03-02 13:22:02,417 - INFO - machamp.model.callback - time_total  : 0:02:32
# 2024-03-02 13:22:02,417 - INFO - machamp.model.callback -
# 2024-03-02 13:22:02,417 - INFO - machamp.model.callback -                train_loss dev_loss train_scores dev_scores
# 2024-03-02 13:22:02,418 - INFO - machamp.model.callback - Best (3)
# 2024-03-02 13:22:02,418 - INFO - machamp.model.callback - dependency_las     3.3056   2.0646       0.2551     0.4850
# 2024-03-02 13:22:02,418 - INFO - machamp.model.callback - upos_accuracy      1.8795   1.3795       0.4749     0.6637
# 2024-03-02 13:22:02,418 - INFO - machamp.model.callback - sum                5.1851   3.4441       0.7300     1.1487
# 2024-03-02 13:22:02,418 - INFO - machamp.model.callback - Epoch 3
# 2024-03-02 13:22:02,418 - INFO - machamp.model.callback - dependency_las     3.3056   2.0646       0.2551     0.4850
# 2024-03-02 13:22:02,418 - INFO - machamp.model.callback - upos_accuracy      1.8795   1.3795       0.4749     0.6637
# 2024-03-02 13:22:02,418 - INFO - machamp.model.callback - sum                5.1851   3.4441       0.7300     1.1487
# 2024-03-02 13:22:02,446 - INFO - machamp.model.callback -
#                 Dev scores (y) over epochs (x)
# ┌────────────────────────────────────────────────────────────┐
# │                                                         ▄▞▀│
# │                                                      ▄▞▀   │
# │                                                   ▄▞▀      │ 0.6
# │                                                ▄▞▀         │
# │                                             ▄▞▀            │
# │                                          ▄▞▀               │
# │                                       ▄▞▀              ▄▄▀▀│
# │                                    ▄▞▀             ▄▄▀▀    │
# │                                 ▄▞▀           ▗▄▄▀▀        │ 0.4
# │                              ▗▞▀          ▗▄▞▀▘            │
# │                         ▄▄▞▀▀▘        ▗▄▞▀▘                │
# │                   ▗▄▄▀▀▀          ▗▄▞▀▘                    │
# │              ▄▄▞▀▀▘           ▄▄▞▀▘                        │
# │        ▗▄▄▀▀▀          ▄▄▄▄▞▀▀                             │
# │   ▄▄▞▀▀▘       ▄▄▄▄▀▀▀▀                                    │
# │▀▀▀     ▄▄▄▄▀▀▀▀                                            │ 0.2
# │▄▄▄▄▀▀▀▀                                                    │
# └────────────────────────────────────────────────────────────┘
#  1                             2                            3
#                         ██ dependency
#                         ██ upos
# 2024-03-02 13:22:02,446 - INFO - machamp.model.callback - Performance of 1.1487 within top 1 models, saving to logs/pilot/2024.03.02_13.19.14/model_3.pt
# 2024-03-02 13:22:03,838 - INFO - machamp.model.callback - Removing old model: logs/pilot/2024.03.02_13.19.14/model_2.pt
# 2024-03-02 13:22:03,917 - INFO - machamp.model.trainer - Epoch 4/20: training
# 100% 112/112 [00:51<00:00,  2.17it/s]
# 2024-03-02 13:22:55,527 - INFO - machamp.modules.allennlp.slanted_triangular - Learning rates for each group:
#
# 2024-03-02 13:22:55,527 - INFO - machamp.modules.allennlp.slanted_triangular - 0: 5.4143808777429475e-05
# 2024-03-02 13:22:55,527 - INFO - machamp.modules.allennlp.slanted_triangular - 1: 5.4143808777429475e-05
# 2024-03-02 13:22:55,527 - INFO - machamp.modules.allennlp.slanted_triangular - 2: 2.05746473354232e-05
# 2024-03-02 13:22:55,528 - INFO - machamp.modules.allennlp.slanted_triangular - Gradual unfreezing finished. Training all layers.
# 2024-03-02 13:22:55,528 - INFO - machamp.model.trainer - Epoch 4: evaluating on dev
# 100% 12/12 [00:02<00:00,  4.61it/s]
# 2024-03-02 13:22:58,135 - INFO - machamp.model.callback - epoch       : 4/20
# 2024-03-02 13:22:58,135 - INFO - machamp.model.callback - best_epoch  : 4
# 2024-03-02 13:22:58,135 - INFO - machamp.model.callback - max_gpu_mem : 2.9916
# 2024-03-02 13:22:58,135 - INFO - machamp.model.callback - cur_ram     : 1.7974
# 2024-03-02 13:22:58,135 - INFO - machamp.model.callback - time_epoch  : 0:00:54
# 2024-03-02 13:22:58,135 - INFO - machamp.model.callback - time_total  : 0:03:28
# 2024-03-02 13:22:58,135 - INFO - machamp.model.callback -
# 2024-03-02 13:22:58,136 - INFO - machamp.model.callback -                train_loss dev_loss train_scores dev_scores
# 2024-03-02 13:22:58,136 - INFO - machamp.model.callback - Best (4)
# 2024-03-02 13:22:58,136 - INFO - machamp.model.callback - dependency_las     2.2858   1.5137       0.4532     0.6460
# 2024-03-02 13:22:58,136 - INFO - machamp.model.callback - upos_accuracy      1.1027   0.7052       0.7417     0.8221
# 2024-03-02 13:22:58,136 - INFO - machamp.model.callback - sum                3.3884   2.2189       1.1949     1.4681
# 2024-03-02 13:22:58,136 - INFO - machamp.model.callback - Epoch 4
# 2024-03-02 13:22:58,136 - INFO - machamp.model.callback - dependency_las     2.2858   1.5137       0.4532     0.6460
# 2024-03-02 13:22:58,136 - INFO - machamp.model.callback - upos_accuracy      1.1027   0.7052       0.7417     0.8221
# 2024-03-02 13:22:58,136 - INFO - machamp.model.callback - sum                3.3884   2.2189       1.1949     1.4681
# 2024-03-02 13:22:58,159 - INFO - machamp.model.callback -
#                 Dev scores (y) over epochs (x)
# ┌────────────────────────────────────────────────────────────┐
# │                                                       ▄▄▞▀▀│ 0.8
# │                                                  ▄▄▞▀▀     │
# │                                             ▗▄▞▀▀          │
# │                                        ▗▄▄▀▀▘              │
# │                                     ▗▄▀▘                ▗▄▄│
# │                                   ▄▞▘               ▄▄▞▀▘  │ 0.6
# │                                ▗▞▀             ▄▄▞▀▀       │
# │                              ▄▀▘          ▄▄▞▀▀            │
# │                           ▄▞▀         ▄▄▀▀                 │
# │                        ▗▄▀        ▄▄▀▀                     │
# │                      ▄▞▘      ▗▄▞▀                         │ 0.4
# │                   ▄▞▀      ▄▞▀▘                            │
# │              ▄▄▞▀▀     ▗▄▀▀                                │
# │         ▄▄▞▀▀      ▗▄▞▀▘                                   │
# │    ▄▄▞▀▀     ▄▄▄▞▀▀▘                                       │
# │▄▄▀▀   ▄▄▄▞▀▀▀                                              │ 0.2
# │▄▄▄▞▀▀▀                                                     │
# └────────────────────────────────────────────────────────────┘
#  1                   2                  3                   4
#                         ██ dependency
#                         ██ upos
# 2024-03-02 13:22:58,159 - INFO - machamp.model.callback - Performance of 1.4681 within top 1 models, saving to logs/pilot/2024.03.02_13.19.14/model_4.pt
# 2024-03-02 13:22:59,561 - INFO - machamp.model.callback - Removing old model: logs/pilot/2024.03.02_13.19.14/model_3.pt
# 2024-03-02 13:22:59,655 - INFO - machamp.model.trainer - Epoch 5/20: training
# 100% 112/112 [00:51<00:00,  2.19it/s]
# 2024-03-02 13:23:50,826 - INFO - machamp.modules.allennlp.slanted_triangular - Learning rates for each group:
#
# 2024-03-02 13:23:50,827 - INFO - machamp.modules.allennlp.slanted_triangular - 0: 7.115007836990596e-05
# 2024-03-02 13:23:50,827 - INFO - machamp.modules.allennlp.slanted_triangular - 1: 7.115007836990596e-05
# 2024-03-02 13:23:50,827 - INFO - machamp.modules.allennlp.slanted_triangular - 2: 2.7037029780564264e-05
# 2024-03-02 13:23:50,827 - INFO - machamp.modules.allennlp.slanted_triangular - Gradual unfreezing finished. Training all layers.
# 2024-03-02 13:23:50,827 - INFO - machamp.model.trainer - Epoch 5: evaluating on dev
# 100% 12/12 [00:02<00:00,  4.24it/s]
# 2024-03-02 13:23:53,658 - INFO - machamp.model.callback - epoch       : 5/20
# 2024-03-02 13:23:53,658 - INFO - machamp.model.callback - best_epoch  : 5
# 2024-03-02 13:23:53,659 - INFO - machamp.model.callback - max_gpu_mem : 2.9916
# 2024-03-02 13:23:53,659 - INFO - machamp.model.callback - cur_ram     : 1.7974
# 2024-03-02 13:23:53,659 - INFO - machamp.model.callback - time_epoch  : 0:00:54
# 2024-03-02 13:23:53,659 - INFO - machamp.model.callback - time_total  : 0:04:24
# 2024-03-02 13:23:53,659 - INFO - machamp.model.callback -
# 2024-03-02 13:23:53,659 - INFO - machamp.model.callback -                train_loss dev_loss train_scores dev_scores
# 2024-03-02 13:23:53,659 - INFO - machamp.model.callback - Best (5)
# 2024-03-02 13:23:53,659 - INFO - machamp.model.callback - dependency_las     1.7795   1.3527       0.5689     0.7012
# 2024-03-02 13:23:53,659 - INFO - machamp.model.callback - upos_accuracy      0.6360   0.4647       0.8516     0.8684
# 2024-03-02 13:23:53,659 - INFO - machamp.model.callback - sum                2.4155   1.8173       1.4205     1.5696
# 2024-03-02 13:23:53,660 - INFO - machamp.model.callback - Epoch 5
# 2024-03-02 13:23:53,660 - INFO - machamp.model.callback - dependency_las     1.7795   1.3527       0.5689     0.7012
# 2024-03-02 13:23:53,660 - INFO - machamp.model.callback - upos_accuracy      0.6360   0.4647       0.8516     0.8684
# 2024-03-02 13:23:53,660 - INFO - machamp.model.callback - sum                2.4155   1.8173       1.4205     1.5696
# 2024-03-02 13:23:53,688 - INFO - machamp.model.callback -
#                 Dev scores (y) over epochs (x)
# ┌────────────────────────────────────────────────────────────┐
# │                                                 ▄▄▄▄▄▞▀▀▀▀▀│
# │                                           ▄▞▀▀▀▀           │ 0.8
# │                                       ▗▄▀▀                 │
# │                                    ▄▄▀▘                    │
# │                                 ▄▞▀                     ▗▄▄│
# │                             ▗▄▀▀               ▄▄▄▄▄▀▀▀▀▘  │
# │                            ▄▘             ▄▞▀▀▀            │
# │                          ▄▀           ▗▄▀▀                 │ 0.6
# │                        ▗▞          ▄▄▀▘                    │
# │                      ▗▞▘        ▄▞▀                        │
# │                     ▄▘       ▄▞▀                           │
# │                   ▄▀      ▗▞▀                              │
# │                 ▗▀      ▄▀▘                                │
# │               ▗▞▘    ▗▞▀                                   │ 0.4
# │            ▗▄▞▘    ▄▀▘                                     │
# │         ▗▄▀▘    ▗▞▀                                        │
# │    ▗▄▄▄▀▘  ▗▄▄▄▞▘                                          │
# └────────────────────────────────────────────────────────────┘
#  1              2              3             4              5
#                         ██ dependency
#                         ██ upos
# 2024-03-02 13:23:53,688 - INFO - machamp.model.callback - Performance of 1.5696 within top 1 models, saving to logs/pilot/2024.03.02_13.19.14/model_5.pt
# 2024-03-02 13:23:55,080 - INFO - machamp.model.callback - Removing old model: logs/pilot/2024.03.02_13.19.14/model_4.pt
# 2024-03-02 13:23:55,163 - INFO - machamp.model.trainer - Epoch 6/20: training
# 100% 112/112 [00:51<00:00,  2.17it/s]
# 2024-03-02 13:24:46,814 - INFO - machamp.modules.allennlp.slanted_triangular - Learning rates for each group:
#
# 2024-03-02 13:24:46,815 - INFO - machamp.modules.allennlp.slanted_triangular - 0: 8.815634796238246e-05
# 2024-03-02 13:24:46,815 - INFO - machamp.modules.allennlp.slanted_triangular - 1: 8.815634796238246e-05
# 2024-03-02 13:24:46,815 - INFO - machamp.modules.allennlp.slanted_triangular - 2: 3.349941222570533e-05
# 2024-03-02 13:24:46,815 - INFO - machamp.modules.allennlp.slanted_triangular - Gradual unfreezing finished. Training all layers.
# 2024-03-02 13:24:46,815 - INFO - machamp.model.trainer - Epoch 6: evaluating on dev
# 100% 12/12 [00:02<00:00,  4.90it/s]
# 2024-03-02 13:24:49,266 - INFO - machamp.model.callback - epoch       : 6/20
# 2024-03-02 13:24:49,266 - INFO - machamp.model.callback - best_epoch  : 6
# 2024-03-02 13:24:49,266 - INFO - machamp.model.callback - max_gpu_mem : 2.9916
# 2024-03-02 13:24:49,266 - INFO - machamp.model.callback - cur_ram     : 1.7979
# 2024-03-02 13:24:49,266 - INFO - machamp.model.callback - time_epoch  : 0:00:54
# 2024-03-02 13:24:49,266 - INFO - machamp.model.callback - time_total  : 0:05:19
# 2024-03-02 13:24:49,266 - INFO - machamp.model.callback -
# 2024-03-02 13:24:49,267 - INFO - machamp.model.callback -                train_loss dev_loss train_scores dev_scores
# 2024-03-02 13:24:49,267 - INFO - machamp.model.callback - Best (6)
# 2024-03-02 13:24:49,267 - INFO - machamp.model.callback - dependency_las     1.3772   1.2143       0.6526     0.7409
# 2024-03-02 13:24:49,267 - INFO - machamp.model.callback - upos_accuracy      0.4271   0.3329       0.8913     0.9088
# 2024-03-02 13:24:49,267 - INFO - machamp.model.callback - sum                1.8043   1.5471       1.5438     1.6497
# 2024-03-02 13:24:49,267 - INFO - machamp.model.callback - Epoch 6
# 2024-03-02 13:24:49,267 - INFO - machamp.model.callback - dependency_las     1.3772   1.2143       0.6526     0.7409
# 2024-03-02 13:24:49,267 - INFO - machamp.model.callback - upos_accuracy      0.4271   0.3329       0.8913     0.9088
# 2024-03-02 13:24:49,267 - INFO - machamp.model.callback - sum                1.8043   1.5471       1.5438     1.6497
# 2024-03-02 13:24:49,290 - INFO - machamp.model.callback -
#                 Dev scores (y) over epochs (x)
# ┌────────────────────────────────────────────────────────────┐
# │                                                 ▄▄▄▄▄▞▀▀▀▀▀│ 0.9
# │                                       ▄▄▄▄▄▀▀▀▀▀           │
# │                                  ▄▞▀▀▀                     │
# │                               ▄▞▀                          │
# │                            ▗▄▀                       ▄▄▄▄▄▟│
# │                         ▗▄▀▘               ▄▄▄▄▞▀▀▀▀▀      │
# │                       ▗▛▘          ▄▄▄▄▀▀▀▀                │
# │                      ▞▘         ▄▞▀                        │
# │                    ▗▀        ▗▄▀                           │ 0.6
# │                   ▞▘      ▗▄▀▘                             │
# │                 ▗▀      ▄▀▘                                │
# │                ▞▘    ▗▞▀                                   │
# │              ▗▀    ▗▞▘                                     │
# │             ▞▘   ▗▞▘                                       │
# │          ▗▄▀   ▄▞▘                                         │
# │        ▄▀▘   ▄▀                                            │
# │   ▗▄▄▞▀  ▄▄▄▀                                              │ 0.3
# └────────────────────────────────────────────────────────────┘
#  1           2           3          4           5           6
#                         ██ dependency
#                         ██ upos
# 2024-03-02 13:24:49,290 - INFO - machamp.model.callback - Performance of 1.6497 within top 1 models, saving to logs/pilot/2024.03.02_13.19.14/model_6.pt
# 2024-03-02 13:24:50,776 - INFO - machamp.model.callback - Removing old model: logs/pilot/2024.03.02_13.19.14/model_5.pt
# 2024-03-02 13:24:50,864 - INFO - machamp.model.trainer - Epoch 7/20: training
# 100% 112/112 [00:50<00:00,  2.21it/s]
# 2024-03-02 13:25:41,581 - INFO - machamp.modules.allennlp.slanted_triangular - Learning rates for each group:
#
# 2024-03-02 13:25:41,582 - INFO - machamp.modules.allennlp.slanted_triangular - 0: 9.778942953020135e-05
# 2024-03-02 13:25:41,582 - INFO - machamp.modules.allennlp.slanted_triangular - 1: 9.778942953020135e-05
# 2024-03-02 13:25:41,582 - INFO - machamp.modules.allennlp.slanted_triangular - 2: 3.7159983221476514e-05
# 2024-03-02 13:25:41,582 - INFO - machamp.modules.allennlp.slanted_triangular - Gradual unfreezing finished. Training all layers.
# 2024-03-02 13:25:41,582 - INFO - machamp.model.trainer - Epoch 7: evaluating on dev
# 100% 12/12 [00:02<00:00,  4.18it/s]
# 2024-03-02 13:25:44,455 - INFO - machamp.model.callback - epoch       : 7/20
# 2024-03-02 13:25:44,456 - INFO - machamp.model.callback - best_epoch  : 7
# 2024-03-02 13:25:44,456 - INFO - machamp.model.callback - max_gpu_mem : 2.9916
# 2024-03-02 13:25:44,456 - INFO - machamp.model.callback - cur_ram     : 1.7979
# 2024-03-02 13:25:44,456 - INFO - machamp.model.callback - time_epoch  : 0:00:53
# 2024-03-02 13:25:44,456 - INFO - machamp.model.callback - time_total  : 0:06:14
# 2024-03-02 13:25:44,456 - INFO - machamp.model.callback -
# 2024-03-02 13:25:44,456 - INFO - machamp.model.callback -                train_loss dev_loss train_scores dev_scores
# 2024-03-02 13:25:44,456 - INFO - machamp.model.callback - Best (7)
# 2024-03-02 13:25:44,456 - INFO - machamp.model.callback - dependency_las     1.1416   1.1183       0.7079     0.7608
# 2024-03-02 13:25:44,456 - INFO - machamp.model.callback - upos_accuracy      0.3059   0.2890       0.9212     0.9191
# 2024-03-02 13:25:44,457 - INFO - machamp.model.callback - sum                1.4475   1.4074       1.6290     1.6799
# 2024-03-02 13:25:44,457 - INFO - machamp.model.callback - Epoch 7
# 2024-03-02 13:25:44,457 - INFO - machamp.model.callback - dependency_las     1.1416   1.1183       0.7079     0.7608
# 2024-03-02 13:25:44,457 - INFO - machamp.model.callback - upos_accuracy      0.3059   0.2890       0.9212     0.9191
# 2024-03-02 13:25:44,457 - INFO - machamp.model.callback - sum                1.4475   1.4074       1.6290     1.6799
# 2024-03-02 13:25:44,480 - INFO - machamp.model.callback -
#                 Dev scores (y) over epochs (x)
# ┌────────────────────────────────────────────────────────────┐
# │                                           ▗▄▄▄▄▀▀▀▀▀▀▀▀▀▀▀▀│
# │                                  ▗▄▄▄▞▀▀▀▀▘                │
# │                             ▄▞▀▀▀▘                         │
# │                          ▗▞▀                               │ 0.8
# │                        ▄▞▘                    ▄▄▄▄▄▄▞▀▀▀▀▀▀│
# │                     ▗▄▀              ▄▄▄▄▀▀▀▀▀             │
# │                   ▗▞▘         ▄▄▄▞▀▀▀                      │
# │                  ▗▘        ▄▀▀                             │
# │                 ▞▘      ▗▄▀                                │ 0.6
# │                ▞      ▗▞▘                                  │
# │              ▗▀     ▄▀▘                                    │
# │             ▗▘    ▄▀                                       │
# │            ▞▘   ▄▀                                         │
# │          ▗▞   ▗▞                                           │ 0.4
# │         ▄▌  ▗▞▘                                            │
# │      ▗▞▀   ▞▘                                              │
# │   ▄▄▞▘ ▗▄▄▀                                                │
# └────────────────────────────────────────────────────────────┘
#  1         2         3         4        5         6         7
#                         ██ dependency
#                         ██ upos
# 2024-03-02 13:25:44,480 - INFO - machamp.model.callback - Performance of 1.6799 within top 1 models, saving to logs/pilot/2024.03.02_13.19.14/model_7.pt
# ...
# 2024-03-02 13:34:27,376 - INFO - machamp.model.callback - upos_accuracy      0.0810   0.2048       0.9749     0.9458
# 2024-03-02 13:34:27,376 - INFO - machamp.model.callback - sum                0.3478   1.6268       1.8903     1.7509
# 2024-03-02 13:34:27,376 - INFO - machamp.model.callback - Epoch 17
# 2024-03-02 13:34:27,376 - INFO - machamp.model.callback - dependency_las     0.2413   1.5135       0.9238     0.8028
# 2024-03-02 13:34:27,376 - INFO - machamp.model.callback - upos_accuracy      0.0739   0.2062       0.9771     0.9451
# 2024-03-02 13:34:27,376 - INFO - machamp.model.callback - sum                0.3153   1.7197       1.9008     1.7479
# 2024-03-02 13:34:27,398 - INFO - machamp.model.callback -
#                 Dev scores (y) over epochs (x)
# ┌────────────────────────────────────────────────────────────┐
# │                  ▗▄▄▄▄▄▄▞▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀│
# │               ▄▄▀▘                                         │
# │           ▗▄▞▀                                             │
# │          ▗▘                    ▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄│ 0.8
# │         ▗▘         ▄▄▄▄▄▀▀▀▀▀▀▀                            │
# │        ▗▘     ▗▄▞▀▀                                        │
# │       ▗▘    ▄▀▘                                            │
# │       ▛   ▞▀                                               │
# │      ▐   ▞                                                 │ 0.6
# │      ▌  ▞                                                  │
# │     ▐  ▞                                                   │
# │     ▌ ▟                                                    │
# │    ▐ ▗▘                                                    │
# │    ▌ ▌                                                     │ 0.4
# │   ▐ ▞                                                      │
# │  ▗▘▗▘                                                      │
# │ ▄▘▄▘                                                       │
# └────────────────────────────────────────────────────────────┘
#                 5                10                 15
#                         ██ dependency
#                         ██ upos
# 2024-03-02 13:34:27,398 - INFO - machamp.model.trainer - Epoch 18/20: training
# 100% 112/112 [00:46<00:00,  2.39it/s]
# 2024-03-02 13:35:14,319 - INFO - machamp.modules.allennlp.slanted_triangular - Learning rates for each group:
#
# 2024-03-02 13:35:14,319 - INFO - machamp.modules.allennlp.slanted_triangular - 0: 1.768875838926174e-05
# 2024-03-02 13:35:14,319 - INFO - machamp.modules.allennlp.slanted_triangular - 1: 1.768875838926174e-05
# 2024-03-02 13:35:14,319 - INFO - machamp.modules.allennlp.slanted_triangular - 2: 6.721728187919462e-06
# 2024-03-02 13:35:14,319 - INFO - machamp.modules.allennlp.slanted_triangular - Gradual unfreezing finished. Training all layers.
# 2024-03-02 13:35:14,319 - INFO - machamp.model.trainer - Epoch 18: evaluating on dev
# 100% 12/12 [00:02<00:00,  5.64it/s]
# 2024-03-02 13:35:16,448 - INFO - machamp.model.callback - epoch       : 18/20
# 2024-03-02 13:35:16,448 - INFO - machamp.model.callback - best_epoch  : 16
# 2024-03-02 13:35:16,448 - INFO - machamp.model.callback - max_gpu_mem : 2.9916
# 2024-03-02 13:35:16,448 - INFO - machamp.model.callback - cur_ram     : 1.8073
# 2024-03-02 13:35:16,448 - INFO - machamp.model.callback - time_epoch  : 0:00:49
# 2024-03-02 13:35:16,448 - INFO - machamp.model.callback - time_total  : 0:15:46
# 2024-03-02 13:35:16,448 - INFO - machamp.model.callback -
# 2024-03-02 13:35:16,449 - INFO - machamp.model.callback -                train_loss dev_loss train_scores dev_scores
# 2024-03-02 13:35:16,449 - INFO - machamp.model.callback - Best (16)
# 2024-03-02 13:35:16,449 - INFO - machamp.model.callback - dependency_las     0.2669   1.4221       0.9154     0.8051
# 2024-03-02 13:35:16,449 - INFO - machamp.model.callback - upos_accuracy      0.0810   0.2048       0.9749     0.9458
# 2024-03-02 13:35:16,449 - INFO - machamp.model.callback - sum                0.3478   1.6268       1.8903     1.7509
# 2024-03-02 13:35:16,449 - INFO - machamp.model.callback - Epoch 18
# 2024-03-02 13:35:16,449 - INFO - machamp.model.callback - dependency_las     0.2171   1.4921       0.9302     0.8040
# 2024-03-02 13:35:16,449 - INFO - machamp.model.callback - upos_accuracy      0.0696   0.2035       0.9789     0.9460
# 2024-03-02 13:35:16,449 - INFO - machamp.model.callback - sum                0.2867   1.6957       1.9091     1.7499
# 2024-03-02 13:35:16,472 - INFO - machamp.model.callback -
#                 Dev scores (y) over epochs (x)
# ┌────────────────────────────────────────────────────────────┐
# │                 ▗▄▄▄▄▄▄▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀│
# │              ▄▄▀▘                                          │
# │           ▄▞▀                                              │
# │          ▞                   ▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄│ 0.8
# │         ▞         ▄▄▄▄▄▀▀▀▀▀▀                              │
# │        ▞      ▄▞▀▀                                         │
# │       ▞    ▄▞▀                                             │
# │      ▗▘  ▄▀                                                │
# │      ▞  ▗▘                                                 │ 0.6
# │     ▗▘ ▗▘                                                  │
# │     ▞ ▗▘                                                   │
# │    ▗▘ ▌                                                    │
# │    ▞ ▞                                                     │
# │   ▗▘▗▘                                                     │ 0.4
# │   ▟ ▌                                                      │
# │  ▗ ▞                                                       │
# │ ▄▘▄▘                                                       │
# └────────────────────────────────────────────────────────────┘
#                5               10                15
#                         ██ dependency
#                         ██ upos
# 2024-03-02 13:35:16,472 - INFO - machamp.model.trainer - Epoch 19/20: training
# 100% 112/112 [00:47<00:00,  2.38it/s]
# 2024-03-02 13:36:03,557 - INFO - machamp.modules.allennlp.slanted_triangular - Learning rates for each group:
#
# 2024-03-02 13:36:03,557 - INFO - machamp.modules.allennlp.slanted_triangular - 0: 1.0406879194630871e-05
# 2024-03-02 13:36:03,557 - INFO - machamp.modules.allennlp.slanted_triangular - 1: 1.0406879194630871e-05
# 2024-03-02 13:36:03,557 - INFO - machamp.modules.allennlp.slanted_triangular - 2: 3.954614093959731e-06
# 2024-03-02 13:36:03,557 - INFO - machamp.modules.allennlp.slanted_triangular - Gradual unfreezing finished. Training all layers.
# 2024-03-02 13:36:03,557 - INFO - machamp.model.trainer - Epoch 19: evaluating on dev
# 100% 12/12 [00:02<00:00,  5.53it/s]
# 2024-03-02 13:36:05,730 - INFO - machamp.model.callback - epoch       : 19/20
# 2024-03-02 13:36:05,730 - INFO - machamp.model.callback - best_epoch  : 19
# 2024-03-02 13:36:05,730 - INFO - machamp.model.callback - max_gpu_mem : 2.9916
# 2024-03-02 13:36:05,730 - INFO - machamp.model.callback - cur_ram     : 1.8073
# 2024-03-02 13:36:05,730 - INFO - machamp.model.callback - time_epoch  : 0:00:49
# 2024-03-02 13:36:05,730 - INFO - machamp.model.callback - time_total  : 0:16:36
# 2024-03-02 13:36:05,730 - INFO - machamp.model.callback -
# 2024-03-02 13:36:05,730 - INFO - machamp.model.callback -                train_loss dev_loss train_scores dev_scores
# 2024-03-02 13:36:05,730 - INFO - machamp.model.callback - Best (19)
# 2024-03-02 13:36:05,730 - INFO - machamp.model.callback - dependency_las     0.1975   1.5248       0.9357     0.8046
# 2024-03-02 13:36:05,731 - INFO - machamp.model.callback - upos_accuracy      0.0659   0.2068       0.9794     0.9468
# 2024-03-02 13:36:05,731 - INFO - machamp.model.callback - sum                0.2634   1.7316       1.9151     1.7514
# 2024-03-02 13:36:05,731 - INFO - machamp.model.callback - Epoch 19
# 2024-03-02 13:36:05,731 - INFO - machamp.model.callback - dependency_las     0.1975   1.5248       0.9357     0.8046
# 2024-03-02 13:36:05,731 - INFO - machamp.model.callback - upos_accuracy      0.0659   0.2068       0.9794     0.9468
# 2024-03-02 13:36:05,731 - INFO - machamp.model.callback - sum                0.2634   1.7316       1.9151     1.7514
# 2024-03-02 13:36:05,754 - INFO - machamp.model.callback -
#                 Dev scores (y) over epochs (x)
# ┌────────────────────────────────────────────────────────────┐
# │                ▗▄▄▄▄▄▄▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀│
# │             ▄▄▀▘                                           │
# │          ▗▄▀▘                                              │
# │         ▐▘                  ▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄│ 0.8
# │        ▗▘        ▄▄▄▄▞▀▀▀▀▀▀                               │
# │       ▗▘     ▄▞▀▀                                          │
# │       ▌   ▗▞▀                                              │
# │      ▞  ▗▛▘                                                │
# │     ▗▘  ▌                                                  │ 0.6
# │     ▐  ▞                                                   │
# │     ▌ ▞                                                    │
# │    ▐ ▗▘                                                    │
# │    ▌ ▌                                                     │
# │   ▐ ▞                                                      │ 0.4
# │   ▞▗▘                                                      │
# │  ▞ ▌                                                       │
# │ ▗▘▟                                                        │
# └────────────────────────────────────────────────────────────┘
#               5               10              15
#                         ██ dependency
#                         ██ upos
# 2024-03-02 13:36:05,755 - INFO - machamp.model.callback - Performance of 1.7514 within top 1 models, saving to logs/pilot/2024.03.02_13.19.14/model_19.pt
# 2024-03-02 13:36:07,182 - INFO - machamp.model.callback - Removing old model: logs/pilot/2024.03.02_13.19.14/model_16.pt
# 2024-03-02 13:36:07,266 - INFO - machamp.model.trainer - Epoch 20/20: training
# 100% 112/112 [00:46<00:00,  2.39it/s]
# 2024-03-02 13:36:54,040 - INFO - machamp.modules.allennlp.slanted_triangular - Learning rates for each group:
#
# 2024-03-02 13:36:54,040 - INFO - machamp.modules.allennlp.slanted_triangular - 0: 3.125e-06
# 2024-03-02 13:36:54,040 - INFO - machamp.modules.allennlp.slanted_triangular - 1: 3.125e-06
# 2024-03-02 13:36:54,040 - INFO - machamp.modules.allennlp.slanted_triangular - 2: 1.1875e-06
# 2024-03-02 13:36:54,040 - INFO - machamp.modules.allennlp.slanted_triangular - Gradual unfreezing finished. Training all layers.
# 2024-03-02 13:36:54,040 - INFO - machamp.model.trainer - Epoch 20: evaluating on dev
# 100% 12/12 [00:02<00:00,  5.61it/s]
# 2024-03-02 13:36:56,182 - INFO - machamp.model.callback - epoch       : 20/20
# 2024-03-02 13:36:56,183 - INFO - machamp.model.callback - best_epoch  : 20
# 2024-03-02 13:36:56,183 - INFO - machamp.model.callback - max_gpu_mem : 2.9916
# 2024-03-02 13:36:56,183 - INFO - machamp.model.callback - cur_ram     : 1.8073
# 2024-03-02 13:36:56,183 - INFO - machamp.model.callback - time_epoch  : 0:00:48
# 2024-03-02 13:36:56,183 - INFO - machamp.model.callback - time_total  : 0:17:26
# 2024-03-02 13:36:56,183 - INFO - machamp.model.callback -
# 2024-03-02 13:36:56,183 - INFO - machamp.model.callback -                train_loss dev_loss train_scores dev_scores
# 2024-03-02 13:36:56,183 - INFO - machamp.model.callback - Best (20)
# 2024-03-02 13:36:56,183 - INFO - machamp.model.callback - dependency_las     0.1872   1.5685       0.9387     0.8056
# 2024-03-02 13:36:56,183 - INFO - machamp.model.callback - upos_accuracy      0.0635   0.2088       0.9800     0.9471
# 2024-03-02 13:36:56,183 - INFO - machamp.model.callback - sum                0.2507   1.7773       1.9187     1.7528
# 2024-03-02 13:36:56,184 - INFO - machamp.model.callback - Epoch 20
# 2024-03-02 13:36:56,184 - INFO - machamp.model.callback - dependency_las     0.1872   1.5685       0.9387     0.8056
# 2024-03-02 13:36:56,184 - INFO - machamp.model.callback - upos_accuracy      0.0635   0.2088       0.9800     0.9471
# 2024-03-02 13:36:56,184 - INFO - machamp.model.callback - sum                0.2507   1.7773       1.9187     1.7528
# 2024-03-02 13:36:56,207 - INFO - machamp.model.callback -
#                 Dev scores (y) over epochs (x)
# ┌────────────────────────────────────────────────────────────┐
# │               ▗▄▄▄▄▄▄▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀│
# │            ▗▄▀▀                                            │
# │          ▄▞▘                                               │
# │         ▛                 ▗▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄│ 0.8
# │        ▞        ▄▄▄▄▞▀▀▀▀▀▘                                │
# │       ▞     ▗▄▀▀                                           │
# │      ▗▘   ▄▀▘                                              │
# │      ▌  ▟▀                                                 │
# │     ▐  ▐                                                   │ 0.6
# │     ▌ ▗▘                                                   │
# │    ▗▘ ▌                                                    │
# │    ▞ ▞                                                     │
# │   ▗▘▐                                                      │
# │   ▐ ▌                                                      │ 0.4
# │   ▌▐                                                       │
# │  ▞▗▘                                                       │
# │ ▐▗▞                                                        │
# └────────────────────────────────────────────────────────────┘
#              5              10              15             20
#                         ██ dependency
#                         ██ upos
# 2024-03-02 13:36:56,208 - INFO - machamp.model.callback - Performance of 1.7528 within top 1 models, saving to logs/pilot/2024.03.02_13.19.14/model_20.pt
# 2024-03-02 13:36:57,689 - INFO - machamp.model.callback - Removing old model: logs/pilot/2024.03.02_13.19.14/model_19.pt
# 2024-03-02 13:36:57,835 - INFO - machamp.model.callback - Best performance obtained in epoch 20 linking model model_20.pt as logs/pilot/2024.03.02_13.19.14/model.pt.
# 2024-03-02 13:36:57,842 - INFO - machamp.model.trainer - Predicting on dev set
# 2024-03-02 13:36:58,766 - INFO - machamp.data.machamp_dataset - Reading /content/machamp/data/pilot/dev-isl-6k.conllu...
# 2024-03-02 13:36:59,533 - INFO - machamp.readers.read_sequence - Stats pilot (/content/machamp/data/pilot/dev-isl-6k.conllu):
# 2024-03-02 13:36:59,533 - INFO - machamp.readers.read_sequence - Lines:      310
# 2024-03-02 13:36:59,534 - INFO - machamp.readers.read_sequence - Words:      5,997
# 2024-03-02 13:36:59,534 - INFO - machamp.readers.read_sequence - Subwords:   8,904
# 2024-03-02 13:36:59,534 - INFO - machamp.readers.read_sequence - Unks:       0
# 2024-03-02 13:36:59,534 - INFO - machamp.readers.read_sequence - Pre-splits: 0
# 2024-03-02 13:36:59,534 - INFO - machamp.data.machamp_dataset - Done reading /content/machamp/data/pilot/dev-isl-6k.conllu (0.0s)
#
# 2024-03-02 13:36:59,535 - ERROR - STDERR - /usr/local/lib/python3.10/dist-packages/torch/utils/data/sampler.py:64: UserWarning: `data_source` argument is not used and will be removed in 2.2.0.You may still have custom implementation that utilizes it.
# 2024-03-02 13:36:59,535 - ERROR - STDERR -   warnings.warn("`data_source` argument is not used and will be removed in 2.2.0."
# 2024-03-02 13:37:03,469 - INFO - machamp.utils.myutils - dependency_las : 0.8056
# 2024-03-02 13:37:03,470 - INFO - machamp.utils.myutils - upos_accuracy  : 0.9471
# 2024-03-02 13:37:03,470 - INFO - machamp.utils.myutils - sum            : 1.7528
# 2024-03-02 13:37:03,470 - INFO - machamp.utils.myutils -

# %% [markdown]
# ## Testing

# %%
! mkdir -p machamp/predictions  # create folder

# %%
! cd machamp; python3 predict.py /content/machamp/logs/pilot/2024.03.02_13.19.14/model.pt /content/machamp/data/pilot/test-fao.conllu predictions/pilot_test.out --device 0  # set device to 1 for CPU
# Out:
# 2024-03-02 13:40:03.465785: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-02 13:40:03.465839: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-02 13:40:03.467249: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-03-02 13:40:04.631784: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-03-02 13:40:05,659 - INFO - __main__ - cmd: predict.py /content/machamp/logs/pilot/2024.03.02_13.19.14/model.pt /content/machamp/data/pilot/test-fao.conllu predictions/pilot_test.out --device 0
#
# 2024-03-02 13:40:05,659 - INFO - __main__ - loading model...
# 2024-03-02 13:40:06,505 - INFO - __main__ - predicting on /content/machamp/data/pilot/test-fao.conllu, saving on predictions/pilot_test.out
# 2024-03-02 13:40:06,775 - INFO - machamp.data.machamp_dataset - Reading /content/machamp/data/pilot/test-fao.conllu...
# 2024-03-02 13:40:08,131 - INFO - machamp.readers.read_sequence - Stats pilot (/content/machamp/data/pilot/test-fao.conllu):
# 2024-03-02 13:40:08,131 - INFO - machamp.readers.read_sequence - Lines:      1,207
# 2024-03-02 13:40:08,131 - INFO - machamp.readers.read_sequence - Words:      9,993
# 2024-03-02 13:40:08,131 - INFO - machamp.readers.read_sequence - Subwords:   19,663
# 2024-03-02 13:40:08,131 - INFO - machamp.readers.read_sequence - Unks:       0
# 2024-03-02 13:40:08,131 - INFO - machamp.readers.read_sequence - Pre-splits: 0
# 2024-03-02 13:40:08,132 - INFO - machamp.data.machamp_dataset - Done reading /content/machamp/data/pilot/test-fao.conllu (1.0s)
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/sampler.py:64: UserWarning: `data_source` argument is not used and will be removed in 2.2.0.You may still have custom implementation that utilizes it.
#   warnings.warn("`data_source` argument is not used and will be removed in 2.2.0."
# 2024-03-02 13:40:15,767 - INFO - machamp.utils.myutils - dependency_las : 0.5490
# 2024-03-02 13:40:15,767 - INFO - machamp.utils.myutils - upos_accuracy  : 0.7965
# 2024-03-02 13:40:15,767 - INFO - machamp.utils.myutils - sum            : 1.3455
# 2024-03-02 13:40:15,767 - INFO - machamp.utils.myutils -
